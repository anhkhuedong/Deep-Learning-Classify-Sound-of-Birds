# %% [markdown]
# ### **Voice of Birds Classification - Deep Learning Models**

# %% [markdown]
# **1. Import data**

# %%
import pandas as pd
import numpy as np
import json
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Dense, Flatten

pd.set_option('display.max_columns', None)
# Out:
# WARNING:tensorflow:From c:\Users\ADMIN\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data_path = r'D:\UCLA\Data projects\Voice of Birds'

with open('output15.json',"r") as fp:
    df = json.load(fp)

X = np.array(df['mfcc'])
y = np.array(df['labels'])

# %%
# Split the data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=135)

# Build model

model = keras.Sequential([
    # input layer
    keras.layers.Flatten(input_shape = (X.shape[1], X.shape[2])),
        
    # 1st hidden layer
    keras.layers.Dense(512, activation='relu'), 
    keras.layers.Dropout(0.1),
    
    # 2st hidden layer
    keras.layers.Dense(256, activation='relu'),
    # keras.layers.Dropout(0.1),

    # 3st hidden layer
    keras.layers.Dense(64, activation='relu'),
    # keras.layers.Dropout(0.1),

    # output layer
    keras.layers.Dense(19,activation = 'softmax')
])        

# Compile network
optimizer = keras.optimizers.Adam(learning_rate = 0.0001)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics = ['accuracy']) 

model.summary()

history = model.fit(X_train,y_train, validation_data = (X_test,y_test), epochs = 50, batch_size = 68)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_4 (Flatten)         (None, 8398)              0
#
#  dense_16 (Dense)            (None, 512)               4300288
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_17 (Dense)            (None, 256)               131328
#
#  dense_18 (Dense)            (None, 64)                16448
#
#  dense_19 (Dense)            (None, 19)                1235
#
# ...
# Total params: 4449299 (16.97 MB)
# Trainable params: 4449299 (16.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 12/12 [==============================] - 3s 110ms/step - loss: 74.1365 - accuracy: 0.1961 - val_loss: 11.9120 - val_accuracy: 0.5468
# Epoch 2/50
# ...
